# %% [markdown]
# # Map Your Google Location History
#
# ## Step 1: Download your Google Location History
#
# Google makes this process very easy. Go here to [download your location history data](https://www.google.com/settings/takeout) and unzip it.

# %% [markdown]
# ## Step 2: Run this script

# %% [markdown]
# ### Preliminaries

# %%
# Import pandas
import pandas as pd

# Import matplotlib and Basemap
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# Import decimal
import decimal

# Set iPython to display visualization inline
# %matplotlib inline

# %% [markdown]
# ### Read in the location history json
#
# Simply change the string to point to where you unzipped your location history json file

# %%
# Create a dataframe from the json file in the filepath
raw = pd.io.json.read_json('/Users/chrisralbon/Downloads/Location History/LocationHistory.json')

# %% [markdown]
# ### Let's take a look at some of the data

# %%
# View the last five rows of the dataframe
raw.tail()
# Out:
#                                                 locations somePointsTruncated
# 369608  {'accuracy': 57, 'latitudeE7': 388976217, 'tim...                True
# 369609  {'accuracy': 52, 'latitudeE7': 388974040, 'tim...                True
# 369610  {'accuracy': 34, 'latitudeE7': 388974020, 'tim...                True
# 369611  {'accuracy': 50, 'latitudeE7': 388974020, 'tim...                True
# 369612  {'accuracy': 1064, 'latitudeE7': 389467326, 't...                True

# %% [markdown]
# ### Expand the locations object into it's own dataframe

# %%
# Expand the locations column into a dataframe
# This lets us move down one level in the json structure
df = raw['locations'].apply(pd.Series)

# %% [markdown]
# ### Take a peak at the data again

# %%
# View the last five rows of the dataframe
df.tail()
# Out:
#         accuracy activitys  altitude  heading  latitudeE7  longitudeE7  \
# 369608        57       NaN       NaN      NaN   388976217   -770434474
# 369609        52       NaN       NaN      NaN   388974040   -770433938
# 369610        34       NaN       NaN      NaN   388974020   -770432626
# 369611        50       NaN       NaN      NaN   388974020   -770432626
# 369612      1064       NaN       NaN      NaN   389467326   -769333633
#
#           timestampMs  velocity
# 369608  1360251651345       NaN
# 369609  1360251591250       NaN
# 369610  1360251521053       NaN
# 369611  1360249108976       NaN
# 369612  1360242137146       NaN

# %% [markdown]
# ### Wrangle the data

# %%
# Create a list from the latitude column
lats = df['latitudeE7']

# Create a list from the longitude column
lons = df['longitudeE7']

# Multiply both lists by -E7 to move the decimal point
# to the correct location
lats = lats * 0.0000001
lons = lons * 0.0000001

# %%
# View the last five list elements
list(lons[-5:])
# Out:
# [-77.043447399999991,
#  -77.04339379999999,
#  -77.043262599999991,
#  -77.043262599999991,
#  -76.933363299999996]

# %%
# Set the precison of getcontext
decimal.getcontext().prec = 6

# Convert the float into a decimal string, then put it back into float
lats = [float(decimal.Decimal("%.6f" % e)) for e in lats]
lons = [float(decimal.Decimal("%.6f" % e)) for e in lons]

# %%
# View the last five list elements
# to check the decimal function worked
list(lons[-5:])
# Out:
# [-77.043447, -77.043394, -77.043263, -77.043263, -76.933363]

# %% [markdown]
# ### Map the data using basemap

# %%
# Create a figure of size 15,7 (i.e. pretty big)
fig = plt.figure(figsize=(15,7))

# Create a map, using the Gall–Peters projection, 
map = Basemap(projection='gall', 
              # with low resolution,
              resolution = 'l', 
              # And threshold 1000
              area_thresh = 1000.0,
              # Centered at 0,0 (i.e null island)
              lat_0=0, lon_0=0)

# Draw the coastlines on the map
map.drawcoastlines()

# Draw country borders on the map
map.drawcountries()

# Fill the land with grey
map.fillcontinents(color = 'gray')

# Draw the map boundaries
map.drawmapboundary()

# Define our longitude and latitude points
x,y = map(lons, lats)

# Plot them using round markers of size 6
map.plot(x, y, 'ro', markersize=6)
 
# Show the map
plt.show()
